# %% [markdown]
# #               🚀 Stock Market Data Analysis Using Alpha Vantage API 🚀

# %% [markdown]
# ### Scraping Daily Stock Data from Alpha Vantage

# %%
import requests
import pandas as pd
import time

# Alpha Vantage API key
API_KEY = '4X5GDXTRCSG5GF63'

# List of stock symbols to scrape data from
stocks = ['AAPL', 'GOOGL', 'AMZN', 'MSFT', 'TSLA']

url = "https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={}&apikey={}"

# Function to get stock data
def get_stock_data(symbol, api_key):
    try:
        response = requests.get(url.format(symbol, api_key))
        response.raise_for_status()  # Raise an exception for HTTP errors
        data = response.json()
        
        print(f"Response for {symbol}: {data}")
        
        if 'Error Message' in data:
            print(f"Error for {symbol}: {data['Error Message']}")
            return []
        
        # Extract only the time series data
        time_series = data.get('Time Series (Daily)', {})
        print(f"Time Series Data for {symbol}: {time_series}")
        
        stock_info = []
        for date, values in time_series.items():
            stock_info.append({
                'Date': date,
                'Stock': symbol,
                'Open': values['1. open'],
                'High': values['2. high'],
                'Low': values['3. low'],
                'Close': values['4. close'],
                'Volume': values['5. volume']
            })
        return stock_info
    except requests.RequestException as e:
        print(f"Request error for {symbol}: {e}")
        return []

# Scrape stock data for each company
all_stock_data = []
for stock in stocks:
    stock_data = get_stock_data(stock, API_KEY)
    all_stock_data.extend(stock_data)
    time.sleep(12)  # To avoid exceeding API rate limits
all_stock_data
# Out:
# Response for AAPL: {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes', '2. Symbol': 'AAPL', '3. Last Refreshed': '2024-09-06', '4. Output Size': 'Compact', '5. Time Zone': 'US/Eastern'}, 'Time Series (Daily)': {'2024-09-06': {'1. open': '223.9500', '2. high': '225.2400', '3. low': '219.7700', '4. close': '220.8200', '5. volume': '48423011'}, '2024-09-05': {'1. open': '221.6250', '2. high': '225.4800', '3. low': '221.5200', '4. close': '222.3800', '5. volume': '36615398'}, '2024-09-04': {'1. open': '221.6600', '2. high': '221.7800', '3. low': '217.4800', '4. close': '220.8500', '5. volume': '43262758'}, '2024-09-03': {'1. open': '228.5500', '2. high': '229.0000', '3. low': '221.1700', '4. close': '222.7700', '5. volume': '50190574'}, '2024-08-30': {'1. open': '230.1900', '2. high': '230.4000', '3. low': '227.4800', '4. close': '229.0000', '5. volume': '52990770'}, '2024-08-29': {'1. open': '230.1000', '2. high': '232.9200', '3. low': '228.8800', '4. c
# ...

# %%
# !pip install mplfinance

import mplfinance as mpf
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(all_stock_data)
df.to_csv('stock_data.csv', index=False)

# %%
df.head()
# Out:
#          Date Stock      Open      High       Low     Close    Volume
# 0  2024-09-06  AAPL  223.9500  225.2400  219.7700  220.8200  48423011
# 1  2024-09-05  AAPL  221.6250  225.4800  221.5200  222.3800  36615398
# 2  2024-09-04  AAPL  221.6600  221.7800  217.4800  220.8500  43262758
# 3  2024-09-03  AAPL  228.5500  229.0000  221.1700  222.7700  50190574
# 4  2024-08-30  AAPL  230.1900  230.4000  227.4800  229.0000  52990770

# %% [markdown]
# #                                               Automating Stocks Data Retrieval

# %%
import requests
import pandas as pd
import time


def Auto_Scaping_data():
        
    # Alpha Vantage API key
    API_KEY = '4X5GDXTRCSG5GF63'
    # List of stock symbols to scrape data from
    stocks = ['AAPL', 'GOOGL', 'AMZN', 'MSFT', 'TSLA']
    
    url = "https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={}&apikey={}"
    
    # Function to get stock data
    def get_stock_data(symbol, api_key):
        try:
            response = requests.get(url.format(symbol, api_key))
            response.raise_for_status()  # Raise an exception for HTTP errors
            data = response.json()
            
            print(f"Response for {symbol}: {data}")
            
            if 'Error Message' in data:
                print(f"Error for {symbol}: {data['Error Message']}")
                return []
            
            # Extract only the time series data
            time_series = data.get('Time Series (Daily)', {})
            print(f"Time Series Data for {symbol}: {time_series}")
            
            stock_info = []
            for date, values in time_series.items():
                stock_info.append({
                    'Date': date,
                    'Stock': symbol,
                    'Open': values['1. open'],
                    'High': values['2. high'],
                    'Low': values['3. low'],
                    'Close': values['4. close'],
                    'Volume': values['5. volume']
                })
            return stock_info
        except requests.RequestException as e:
            print(f"Request error for {symbol}: {e}")
            return []
    
    # Scrape stock data for each company
    all_stock_data = []
    for stock in stocks:
        stock_data = get_stock_data(stock, API_KEY)
        all_stock_data.extend(stock_data)
        time.sleep(12)  # To avoid exceeding API rate limits
    all_stock_data

    if not os.path.isfile(r'C:\Users\LOGIN-SOLUTIOn\Documents\Data_Analyst\DataSets_+sql\csv_files\stock_data.csv'):
        df.to_csv(r'C:\Users\LOGIN-SOLUTIOn\Documents\Data_Analyst\DataSets_+sql\csv_files\stock_data.csv',index=False)
    else:
        df.to_csv(r'C:\Users\LOGIN-SOLUTIOn\Documents\Data_Analyst\DataSets_+sql\csv_files\stock_data.csv',mode='a',header=False,index=False)

# %%
import os 
from datetime import datetime
from time import time
from time import sleep

for i in range(3):     # Is limit of using this API in a day!
    API_Runner()
    print("Run Sucessfully")
    sleep(12) 

exit()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    500 non-null    object
#  1   Stock   500 non-null    object
#  2   Open    500 non-null    object
#  3   High    500 non-null    object
#  4   Low     500 non-null    object
#  5   Close   500 non-null    object
#  6   Volume  500 non-null    object
# dtypes: object(7)
# memory usage: 27.5+ KB

# %%
df['Close'] = pd.to_numeric(df['Close'], errors='coerce')
df['Low'] = pd.to_numeric(df['Low'], errors='coerce')
df['High'] = pd.to_numeric(df['High'], errors='coerce')
df['Open'] = pd.to_numeric(df['Open'], errors='coerce')
df['Volume'] = pd.to_numeric(df['Volume'], errors='coerce')

# %%
df.set_index(df['Date'], inplace=True)

# %%
df.head()
# Out:
#                   Date Stock     Open    High     Low   Close    Volume
# Date
# 2024-09-06  2024-09-06  AAPL  223.950  225.24  219.77  220.82  48423011
# 2024-09-05  2024-09-05  AAPL  221.625  225.48  221.52  222.38  36615398
# 2024-09-04  2024-09-04  AAPL  221.660  221.78  217.48  220.85  43262758
# 2024-09-03  2024-09-03  AAPL  228.550  229.00  221.17  222.77  50190574
# 2024-08-30  2024-08-30  AAPL  230.190  230.40  227.48  229.00  52990770

# %%
df.drop(columns='Date',inplace=True)

# %%
df.head()
# Out:
#            Stock     Open    High     Low   Close    Volume
# Date
# 2024-09-06  AAPL  223.950  225.24  219.77  220.82  48423011
# 2024-09-05  AAPL  221.625  225.48  221.52  222.38  36615398
# 2024-09-04  AAPL  221.660  221.78  217.48  220.85  43262758
# 2024-09-03  AAPL  228.550  229.00  221.17  222.77  50190574
# 2024-08-30  AAPL  230.190  230.40  227.48  229.00  52990770

# %%
df.index = pd.to_datetime(df.index)

# %%
df.head()
# Out:
#            Stock     Open    High     Low   Close    Volume
# Date
# 2024-09-06  AAPL  223.950  225.24  219.77  220.82  48423011
# 2024-09-05  AAPL  221.625  225.48  221.52  222.38  36615398
# 2024-09-04  AAPL  221.660  221.78  217.48  220.85  43262758
# 2024-09-03  AAPL  228.550  229.00  221.17  222.77  50190574
# 2024-08-30  AAPL  230.190  230.40  227.48  229.00  52990770

# %%
np.unique(df['Stock'])
# Out:
# array(['AAPL', 'AMZN', 'GOOGL', 'MSFT', 'TSLA'], dtype=object)

# %% [markdown]
# # Price and Volume trend

# %%
import mplfinance as mpf
import matplotlib.pyplot as plt

def plot_stock(stock_symbol):
    # Filter the DataFrame for the selected stock
    stock_data = df[df['Stock'] == stock_symbol]
    
    if stock_data.empty:
        print(f"No data available for stock: {stock_symbol}")
        return
    
    # Create the candlestick chart
    mpf.plot(stock_data, type='candle', style='charles', 
             title=f"{stock_symbol} Candlestick Chart", 
             ylabel='Price (USD)', 
             volume=True, 
             mav=(3,6,9))  # Moving averages for visual guidance (optional)
    
plot_stock('AAPL')    # Stock: ['AAPL', 'AMZN', 'GOOGL', 'MSFT', 'TSLA']

# %% [markdown]
# # Price Volatility
# <!-- Volatility refers to the rate at which the stock price increases or decreases for a given set of returns. High volatility can indicate risk or opportunities in the stock.
# Rolling Standard Deviation: Measure of price fluctuations over a certain period. -->

# %%
df['Volatility'] = df['Close'].rolling(window=15).std()

# %%
import mplfinance as mpf
import matplotlib.pyplot as plt
import seaborn as sns

def Price_Volatility(Stock_name):

    Stock_Data2 = df[df['Stock'] == Stock_name]

    if Stock_Data2.empty:
        print(f"No data available for stock: {Stock_name}")
        return
        
    Stock_Data2['Volatility'].plot(figsize=(8, 5), title="Stock Price Volatility",color = '#006400')
    plt.xlabel('Date')
    plt.ylabel('Volatility (15-day rolling std. deviation)')
    plt.show()

Price_Volatility('AAPL')    # Stock: ['AAPL', 'AMZN', 'GOOGL', 'MSFT', 'TSLA']

# %% [markdown]
# # Trading Volume Analysis
# <!-- Visualize the daily trading volume to observe trends in trading activity. A significant increase in trading volume often accompanies price breakouts or shifts in trends. -->

# %%
def Trading_Volume(stock_name):

    Stock_Data3 = df[df['Stock'] == stock_name]

    if Stock_Data3.empty:
        print(f"No data available for stock: {stock_name}")
        return
        
    fig, ax1 = plt.subplots(figsize=(8, 6))
    
    ax1.plot(Stock_Data3.index, Stock_Data3['Close'], color='b', label='Closing Price')
    ax1.set_xlabel('Date')
    ax1.set_ylabel('Closing Price (USD)', color='b')
    
    ax2 = ax1.twinx()
    ax2.bar(Stock_Data3.index, Stock_Data3['Volume'], alpha=0.4, color='orange', label='Volume')
    ax2.set_ylabel('Volume', color='#ffd700')
    
    plt.title("Closing Price vs. Volume")
    plt.grid(visible=None)
    plt.show()

Trading_Volume('AAPL')     # Stock: ['AAPL', 'AMZN', 'GOOGL', 'MSFT', 'TSLA']

# %% [markdown]
# # Relative Strength Index (RSI)
# <!-- The RSI is a momentum indicator used to identify overbought or oversold conditions in a stock. It oscillates between 0 and 100, with values above 70 indicating overbought conditions and below 30 indicating oversold conditions. -->

# %%
def calculate_rsi(data, window=14):
    
    delta = data['Close'].diff(1)
    gain = (delta.where(delta > 0, 0)).rolling(window=window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=window).mean()

    RS = gain / loss
    RSI = 100 - (100 / (1 + RS))
    return RSI

df['RSI'] = calculate_rsi(df)

# %%
def RSI_vis(Stock_Name):

    Stock_Data4 = df[df['Stock'] == Stock_Name]

    if Stock_Data4.empty:
        print(f"No data available for stock: {Stock_Name}")
        return
    Stock_Data4['RSI'].plot(figsize=(10, 6), title="Relative Strength Index (RSI)")
    plt.axhline(70, linestyle='--', alpha=0.5, color='red')
    plt.axhline(30, linestyle='--', alpha=0.5, color='green')
    # plt.grid(visible=None)
    plt.show()

RSI_vis('AAPL')     # Stock: ['AAPL', 'AMZN', 'GOOGL', 'MSFT', 'TSLA']

# %% [markdown]
# # Price Correlation Between Stocks
# <!-- If you have data for multiple stocks, you can analyze how correlated they are. Highly correlated stocks tend to move together, which can help in portfolio diversification. -->

# %%
import seaborn as sns

stock_prices = df.pivot(columns='Stock', values='Close')
correlation_matrix = stock_prices.corr()

plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Stock Closing Price Correlation Heatmap")
plt.show()

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('_mpl-gallery-nogrid')
